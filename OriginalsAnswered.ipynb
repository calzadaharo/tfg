# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('resultados_definitivos/OriginalsAnswered.json') as file:
    result = json.load(file)

# %%
result
# Out:
# {'views': [{'time': 46900568,
#    'originals': 4317896,
#    'no-answered': 3699131,
#    'percentage-isolated': 85.66975675189954,
#    'percentage-answered': 14.330243248100459}]}

# %%
data = [result['views'][0]['originals'],result['views'][0]['no-answered']]

# %%
data
# Out:
# [4317896, 3699131]

# %%
annotations = [round(result['views'][0]['percentage-answered'],2),round(result['views'][0]['percentage-isolated'],2)]

# %%
annotations
# Out:
# [14.33, 85.67]

# %%
preparado = pd.Series(data[0])

# %%
preparado2 = pd.Series(data[1])

# %%
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax=preparado.plot.barh(label="Con respuesta " +str(annotations[0])+'%', color='darkorange')

# %%
ax=preparado2.plot.barh(alpha = 1,label="Sin respuesta " + str(annotations[1])+'%',color='darkblue')

# %%
ax.legend()

# %%
plt.title("Originales respondidos y originales no respondidos")
# Out:
# Text(0.5, 1.0, 'Originales respondidos y originales no respondidos')

# %%
plt.savefig('OriginalsAnswered.jpg')
