# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('ConnectedComponentsDraw.json') as file:
    output = json.load(file)

# %%
values=output['views'][0]['top5']

# %%
freqs = []

# %%
for line in values:
    freqs.append(line['freq'])

# %%
df = pd.DataFrame(freqs)

# %%
data = plt.boxplot(freqs, boxprops=dict(color='darkblue'),
            capprops=dict(color='darkblue'),
            whiskerprops=dict(color='darkblue'),
            flierprops=dict(color='darkblue', markeredgecolor='darkblue'),
            medianprops=dict(color='darkblue'))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.yscale('log')

# %%
plt.title('Distribución de número de nodos de cada conversación')
# Out:
# Text(0.5, 1.0, 'Distribución de número de nodos de cada conversación')
