# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('AnswersAverageDraw.json') as file:
    output = json.load(file)

# %%
output
# Out:
# {'views': [{'time': 24511068,
#    'originals': 51213,
#    'answers': 193029,
#    'average-thread': 3.7691406478823737}]}

# %%
data = [output['views'][0]['originals'],output['views'][0]['answers']]

# %%
data
# Out:
# [51213, 193029]

# %%
preparado=pd.Series(data,index=['Conversaciones','Respuestas'])

# %%
media=round(output['views'][0]['average-thread'],2)

# %%
ax=preparado.plot.bar(rot=0,title="Conversación media = "+str(media), color=['darkblue','darkorange'])
# Out:
# <img src="data:image/png;base64,..." width="640">
