# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('resultados_definitivos/DepthTree.json') as file:
    output = json.load(file)

# %%
threads=output['views'][0]['distrib'] #CAMBIAR POR 'distrib'

# %%
threads
# Out:
# [{'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 3},
#  {'size': 7, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 8, 'max thread': 3},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 5, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 13, 'max thread': 3},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 95, 'max thread': 8},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 3},
#  {'size': 10, 'max thread': 5},
#  {'size': 9, 'max thread': 8},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 19, 'max thread': 11},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 19, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 7, 'max thread': 5},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 6, 'max thread': 6},
#  {'size': 27, 'max thread': 11},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 9, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 6, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 6},
#  {'size': 5, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 6, 'max thread': 3},
#  {'size': 7, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 4, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 6, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 40, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 12, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 42, 'max thread': 20},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 6, 'max thread': 4},
#  {'size': 3, 'max thread': 0},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 6, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 45, 'max thread': 14},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 11, 'max thread': 5},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 14, 'max thread': 11},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 7, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 11},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 4},
#  {'size': 12, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 6, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 4},
#  {'size': 4, 'max thread': 3},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 17, 'max thread': 4},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 7},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 0},
#  {'size': 6, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 2},
#  {'size': 7, 'max thread': 6},
#  {'size': 5, 'max thread': 2},
#  {'size': 9, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 0},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 14, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 6},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 25, 'max thread': 19},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 19, 'max thread': 16},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 6, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 15, 'max thread': 9},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 9, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 6, 'max thread': 6},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 9, 'max thread': 2},
#  {'size': 39, 'max thread': 17},
#  {'size': 2, 'max thread': 2},
#  {'size': 32, 'max thread': 20},
#  {'size': 10, 'max thread': 10},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 4, 'max thread': 4},
#  {'size': 7, 'max thread': 2},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 28, 'max thread': 10},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 119, 'max thread': 44},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 37, 'max thread': 22},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 23, 'max thread': 8},
#  {'size': 6, 'max thread': 0},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 5},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 13, 'max thread': 4},
#  {'size': 5, 'max thread': 5},
#  {'size': 7, 'max thread': 4},
#  {'size': 5, 'max thread': 4},
#  {'size': 6, 'max thread': 6},
#  {'size': 8, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 14, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 7, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 10, 'max thread': 6},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 5},
#  {'size': 4, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 19, 'max thread': 6},
#  {'size': 6, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 9, 'max thread': 6},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 9},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 5, 'max thread': 3},
#  {'size': 4, 'max thread': 3},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 6},
#  {'size': 5, 'max thread': 5},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 3},
#  {'size': 6, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 22, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 10, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 9, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 9, 'max thread': 5},
#  {'size': 9, 'max thread': 7},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 8},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 44, 'max thread': 15},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 2},
#  {'size': 37, 'max thread': 14},
#  {'size': 7, 'max thread': 6},
#  {'size': 8, 'max thread': 7},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 13, 'max thread': 6},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 32, 'max thread': 27},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 5, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 9, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 14, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 10, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 11, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 6},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 10, 'max thread': 10},
#  {'size': 37, 'max thread': 8},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 7},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 12, 'max thread': 0},
#  {'size': 6, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 8, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 28, 'max thread': 5},
#  {'size': 3, 'max thread': 2},
#  {'size': 17, 'max thread': 10},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 14, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 6, 'max thread': 6},
#  {'size': 4, 'max thread': 2},
#  {'size': 10, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 7},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 26, 'max thread': 5},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 4},
#  {'size': 14, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 0},
#  {'size': 120, 'max thread': 45},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 9, 'max thread': 9},
#  {'size': 2, 'max thread': 2},
#  {'size': 20, 'max thread': 9},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 3},
#  {'size': 9, 'max thread': 9},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 8, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 6, 'max thread': 6},
#  {'size': 9, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 4},
#  {'size': 9, 'max thread': 8},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 7},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 0},
#  {'size': 15, 'max thread': 5},
#  {'size': 9, 'max thread': 9},
#  {'size': 7, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 25, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 44, 'max thread': 13},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 0},
#  {'size': 8, 'max thread': 7},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 9, 'max thread': 6},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 8, 'max thread': 6},
#  {'size': 24, 'max thread': 13},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 2},
#  {'size': 9, 'max thread': 5},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 4},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 3},
#  {'size': 5, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 4},
#  {'size': 5, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 6, 'max thread': 6},
#  {'size': 3, 'max thread': 3},
#  {'size': 20, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 17, 'max thread': 2},
#  {'size': 18, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 16, 'max thread': 12},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 11, 'max thread': 11},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 5, 'max thread': 2},
#  {'size': 18, 'max thread': 8},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 65, 'max thread': 4},
#  {'size': 4, 'max thread': 4},
#  {'size': 4, 'max thread': 3},
#  {'size': 5, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 6, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 103, 'max thread': 32},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 10, 'max thread': 9},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 0},
#  {'size': 4, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 5, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 9, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 5},
#  {'size': 3, 'max thread': 3},
#  {'size': 12, 'max thread': 10},
#  {'size': 3, 'max thread': 3},
#  {'size': 7, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 4},
#  {'size': 2, 'max thread': 2},
#  {'size': 19, 'max thread': 8},
#  {'size': 10, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 8, 'max thread': 5},
#  {'size': 6, 'max thread': 4},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 9, 'max thread': 3},
#  {'size': 5, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 11, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 8, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 7, 'max thread': 6},
#  {'size': 6, 'max thread': 5},
#  {'size': 3, 'max thread': 3},
#  {'size': 5, 'max thread': 4},
#  {'size': 9, 'max thread': 9},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 12, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 3, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 7, 'max thread': 2},
#  {'size': 6, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 6, 'max thread': 6},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 3},
#  {'size': 7, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 20, 'max thread': 10},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 8, 'max thread': 8},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 4, 'max thread': 2},
#  {'size': 11, 'max thread': 7},
#  {'size': 2, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 6, 'max thread': 4},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 7, 'max thread': 3},
#  {'size': 13, 'max thread': 10},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 9, 'max thread': 6},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 10, 'max thread': 0},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 0},
#  {'size': 7, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 4},
#  {'size': 3, 'max thread': 3},
#  {'size': 4, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 20, 'max thread': 5},
#  {'size': 17, 'max thread': 6},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 4, 'max thread': 2},
#  {'size': 7, 'max thread': 5},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 4, 'max thread': 4},
#  {'size': 5, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 3, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 2, 'max thread': 2},
#  {'size': 5, 'max thread': 5},
#  {'size': 3, 'max thread': 3},
#  {'size': 3, 'max thread': 3},
#  {'size': 7, 'max thread': 3},
#  {'size': 8, 'max thread': 8},
#  {'size': 2, 'max thread': 2},
#  {'size': 37, 'max thread': 2},
#  ...]

# %%
sizes=[]; maxThreads=[]

# %%
for line in threads:
    if(line['max thread'] != 0):
        sizes.append(line['size'])
        maxThreads.append(line['max thread'])

# %%
fig=plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
sns.regplot(x=sizes ,y=maxThreads, color='darkorange')
# Out:
# <AxesSubplot:>

# %%
plt.xlabel('Tamaño')
# Out:
# Text(0.5, 0, 'Tamaño')

# %%
plt.ylabel('Thread máximo')
# Out:
# Text(0, 0.5, 'Thread máximo')

# %%
plt.title('Distribución del tamaño y el hilo máximo por cada isla')
# Out:
# Text(0.5, 1.0, 'Distribución del tamaño y el hilo máximo por cada isla')

# %%
fig1=plt.figure()
first = sns.regplot(x=sizes ,y=maxThreads, x_estimator=np.mean, color='darkorange')
plt.xlim([0,50])
plt.ylim([0,50])
plt.xlabel('Tamaño')
plt.ylabel('Thread máximo')
plt.title('Del cero al cincuenta')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Del cero al cincuenta')

# %%
fig2=plt.figure()
first = sns.regplot(x=sizes ,y=maxThreads, x_estimator=np.mean, color='darkorange')
plt.xlim([51,100])
plt.ylim([0,100])
plt.xlabel('Tamaño')
plt.ylabel('Thread máximo')
plt.title('Del cincuenta y uno al cien')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Del cincuenta y uno al cien')

# %%
fig3=plt.figure()
first = sns.regplot(x=sizes ,y=maxThreads, x_estimator=np.mean, color='darkorange')
plt.xlim([101,200])
plt.ylim([0,150])
plt.xlabel('Tamaño')
plt.ylabel('Thread máximo')
plt.title('Del ciento uno al doscientos')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Del ciento uno al doscientos')

# %%
fig4=plt.figure()
first = sns.regplot(x=sizes ,y=maxThreads, x_estimator=np.mean, color='darkorange')
plt.xlim([201,400])
plt.ylim([0,175])
plt.xlabel('Tamaño')
plt.ylabel('Thread máximo')
plt.title('Del doscientos uno al cuatrocientos')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Del doscientos uno al cuatrocientos')

# %%
fig5=plt.figure()
first = sns.regplot(x=sizes ,y=maxThreads, x_estimator=np.mean, color='darkorange')
plt.xlim([401,600])
plt.ylim([0,175])
plt.xlabel('Tamaño')
plt.ylabel('Thread máximo')
plt.title('Del cuatrocientos uno al seiscientos')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Del cuatrocientos uno al seiscientos')

# %%
fig6=plt.figure()
first = sns.regplot(x=sizes ,y=maxThreads, x_estimator=np.mean, color='darkorange')
plt.xlim([601,915])
plt.ylim([0,175])
plt.xlabel('Tamaño')
plt.ylabel('Thread máximo')
plt.title('Del seiscientos uno al novecientos quince')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Del seiscientos uno al novecientos quince')

# %%
fig6.savefig('DepthTree6.jpg')
