# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('resultados_definitivos/DegreeOriginalsTime/DegreeOriginalsHourHour.json') as file:
    hours=json.load(file)

# %%
with open('resultados_definitivos/DegreeOriginalsTime/DegreeOriginalsDayHour.json') as file:
    days=json.load(file)

# %%
with open('resultados_definitivos/DegreeOriginalsTime/DegreeOriginalsWeekHour.json') as file:
    weeks=json.load(file)

# %%
with open('resultados_definitivos/DegreeOriginalsTime/DegreeOriginalsMonthHour.json') as file:
    months=json.load(file)

# %%
hours
# Out:
# {'views': [{'time': 19281517,
#    'originals': 1,
#    'answers': 0,
#    "don't-know": 0,
#    'relation': 0.0,
#    'original-per-answer': inf,
#    'percentage-originals': 100.0,
#    'percentage-answers': 0.0},
#   {'time': 19285117,
#    'originals': 0,
#    'answers': 0,
#    "don't-know": 0,
#    'relation': nan,
#    'original-per-answer': nan,
#    'percentage-originals': nan,
#    'percentage-answers': nan},
#   {'time': 19288717,
#    'originals': 0,
#    'answers': 0,
#    "don't-know": 0,
#    'relation': nan,
#    'original-per-answer': nan,
#    'percentage-originals': nan,
#    'percentage-answers': nan},
#   {'time': 19292317,
#    'originals': 0,
#    'answers': 0,
#    "don't-know": 0,
#    'relation': nan,
#    'original-per-answer': nan,
#    'percentage-originals': nan,
#    'percentage-answers': nan},
#   {'time': 19295917,
#    'originals': 3,
#    'answers': 1,
#    "don't-know": 0,
#    'relation': 0.3333333333333333,
#    'original-per-answer': 3.0,
# ...

# %%
originals=[]; answers=[]; degree=[];

# %%
originalsH=[]; answersH=[]; degreeH=[];
for line in hours['views']:
    originalsH.append(line['originals'])
    answersH.append(line['answers'])
    degreeH.append(line['original-per-answer'])

# %%
originals.append(sum(originalsH)/len(originalsH))
answers.append(sum(answersH)/len(originalsH))
# Out:
# 4871354

# %%
originalsD=[]; answersD=[]; degreeD=[];
for line in days['views']:
    originalsD.append(line['originals'])
    answersD.append(line['answers'])
    degreeD.append(line['original-per-answer'])

# %%
len(degreeH)
# Out:
# 7673
