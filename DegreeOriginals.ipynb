# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import json

# %%
with open('resultados_definitivos/DegreeOriginals.json') as file:
    data = json.load(file)

# %%
for line in data['views']: print(line)
# Out:
# {'time': 46900568, 'originals': 4317896, 'answers': 2261908, "don't-know": 47779, 'relation': 0.5238449467055251, 'original-per-answer': 1.9089618145388763, 'percentage-originals': 65.62347449863249, 'percentage-answers': 34.37652550136752}

# %%
nombres=['Originales', 'Respuestas']

# %%
datos = [data['views'][0]['originals'],data['views'][0]['answers']]

# %%
preparado=pd.Series(datos,index=nombres)

# %%
ax=preparado.plot.bar(rot=0,title='Originales vs respuestas',color=['darkblue','darkorange'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
anotaciones = [round(data['views'][0]['percentage-originals'],2),round(data['views'][0]['percentage-answers'],2)]

# %%
anotaciones
# Out:
# [65.62, 34.38]

# %%
ax.annotate(str(anotaciones[0])+'%', xy=(ax.patches[0].get_x() + ax.patches[0].get_width() / 2,ax.patches[0].get_height()),
           va='center',ha='center', xytext=(0, 6),textcoords='offset points')
# Out:
# Text(0, 6, '65.62%')

# %%
ax.annotate(str(anotaciones[1])+'%', xy=(ax.patches[1].get_x() + ax.patches[1].get_width() / 2,ax.patches[1].get_height()),
           va='center',ha='center', xytext=(0, 6),textcoords='offset points')
# Out:
# Text(0, 6, '34.38%')

# %%
datos
# Out:
# [4317896, 2261908]

# %%
#plt.savefig('DegreeOriginals.jpg')

# %%
grouped=[]
resultado=[]
resultado.append(datos[0])
grouped.append(resultado)
result=[]
result.append(datos[1])
grouped.append(result)

# %%
grouped
# Out:
# [[4317896], [2261908]]

# %%
buenas=[]
buenas.append(datos)

# %%
datos
# Out:
# [4317896, 2261908]

# %%
df = pd.DataFrame({'originales': grouped[0],
                   'respuestas': grouped[1]}, index=['1'])

# %%
fig1 = plt.figure()
df.plot.barh(stacked=True, color=['darkblue','darkorange'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
plt.title('Otra representación de Degree Originals')
# Out:
# Text(0.5, 1.0, 'Otra representación de Degree Originals')

# %%
plt.savefig('resultados_definitivos/correcciones/DegreeOriginals.jpg')
