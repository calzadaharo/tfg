# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('resultados_definitivos/DegreeOriginalsTime/DegreeOriginalsHourHour.json') as file:
    output=json.load(file)

# %%
times=[]; degrees=[];data=[]

# %%
for result in output['views']:
    line=[]
    line.append(result['originals'])
    line.append(result['answers'])
    times.append(result['time']/60/60)
    line.append(result['original-per-answer'])
    data.append(line)

# %%
df = pd.DataFrame(data,columns=['Originales','Respuestas','Relación'],index=times)

# %%
df.plot(color=['darkblue','darkorange','green'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
plt.yscale('log')

# %%
plt.title('Relación entre mensajes originales y respuestas cada hora')
# Out:
# Text(0.5, 1.0, 'Relación entre mensajes originales y respuestas cada hora')

# %%
plt.savefig('resultados_definitivos/DegreeOriginalsTime/DegreeOriginalsHour.jpg')
