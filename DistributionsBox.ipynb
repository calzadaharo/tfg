# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('resultados_definitivos/Distributions.json') as file:
    output = json.load(file)

# %%
withOriginals=output['views'][0]['degDist']

# %%
answers=output['views'][0]['answerDistribution']

# %%
oriExpanded = []; ansExpanded = []

# %%
withOriginals
# Out:
# [{'degree': 69, 'freq': 9},
#  {'degree': 138, 'freq': 2},
#  {'degree': 101, 'freq': 3},
#  {'degree': 0, 'freq': 3698486},
#  {'degree': 88, 'freq': 4},
#  {'degree': 115, 'freq': 1},
#  {'degree': 217, 'freq': 1},
#  {'degree': 5, 'freq': 14076},
#  {'degree': 120, 'freq': 1},
#  {'degree': 247, 'freq': 1},
#  {'degree': 10, 'freq': 2342},
#  {'degree': 56, 'freq': 14},
#  {'degree': 142, 'freq': 1},
#  {'degree': 42, 'freq': 42},
#  {'degree': 24, 'freq': 270},
#  {'degree': 37, 'freq': 67},
#  {'degree': 25, 'freq': 231},
#  {'degree': 52, 'freq': 23},
#  {'degree': 14, 'freq': 1069},
#  {'degree': 184, 'freq': 1},
#  {'degree': 125, 'freq': 3},
#  {'degree': 357, 'freq': 1},
#  {'degree': 20, 'freq': 417},
#  {'degree': 46, 'freq': 32},
#  {'degree': 93, 'freq': 4},
#  {'degree': 57, 'freq': 8},
#  {'degree': 78, 'freq': 2},
#  {'degree': 29, 'freq': 181},
#  {'degree': 216, 'freq': 1},
#  {'degree': 179, 'freq': 1},
#  {'degree': 106, 'freq': 1},
# ...

# %%
for line in withOriginals:
    for i in range(line['freq']):
        oriExpanded.append(line['degree'])

# %%
for line in answers:
    for i in range(line['freq']):
        ansExpanded.append(line['weight'])

# %%
plt.boxplot([oriExpanded,ansExpanded])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fa6c72f9400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fa6c72f9ac0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fa6c72f90a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7fa6c6af21c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa6c6af2520>,
# ...
#  'means': []}

# %%
plt.yscale('log')
