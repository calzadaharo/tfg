# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('DistributionsDraw.json') as file:
    output = json.load(file)

# %%
withOriginals=output['views'][0]['degDist']

# %%
answers=output['views'][0]['answerDistribution']

# %%
oriExpanded = []; ansExpanded = []

# %%
withOriginals
# Out:
# [{'degree': 0, 'freq': 255742},
#  {'degree': 5, 'freq': 951},
#  {'degree': 10, 'freq': 77},
#  {'degree': 142, 'freq': 2},
#  {'degree': 24, 'freq': 8},
#  {'degree': 37, 'freq': 2},
#  {'degree': 25, 'freq': 14},
#  {'degree': 14, 'freq': 27},
#  {'degree': 20, 'freq': 17},
#  {'degree': 46, 'freq': 1},
#  {'degree': 57, 'freq': 1},
#  {'degree': 29, 'freq': 8},
#  {'degree': 1, 'freq': 154995},
#  {'degree': 6, 'freq': 486},
#  {'degree': 60, 'freq': 1},
#  {'degree': 28, 'freq': 4},
#  {'degree': 38, 'freq': 2},
#  {'degree': 70, 'freq': 1},
#  {'degree': 21, 'freq': 15},
#  {'degree': 33, 'freq': 5},
#  {'degree': 9, 'freq': 124},
#  {'degree': 13, 'freq': 35},
#  {'degree': 41, 'freq': 2},
#  {'degree': 2, 'freq': 83679},
#  {'degree': 32, 'freq': 3},
#  {'degree': 34, 'freq': 2},
#  {'degree': 45, 'freq': 2},
#  {'degree': 64, 'freq': 1},
#  {'degree': 17, 'freq': 23},
#  {'degree': 22, 'freq': 11},
#  {'degree': 27, 'freq': 6},
#  {'degree': 12, 'freq': 59},
#  {'degree': 81, 'freq': 1},
#  {'degree': 7, 'freq': 237},
#  {'degree': 39, 'freq': 2},
#  {'degree': 66, 'freq': 1},
#  {'degree': 3, 'freq': 10573},
#  {'degree': 35, 'freq': 3},
#  {'degree': 355, 'freq': 1},
#  {'degree': 48, 'freq': 1},
#  {'degree': 18, 'freq': 19},
#  {'degree': 50, 'freq': 1},
#  {'degree': 16, 'freq': 20},
#  {'degree': 31, 'freq': 6},
#  {'degree': 11, 'freq': 66},
#  {'degree': 143, 'freq': 1},
#  {'degree': 43, 'freq': 2},
#  {'degree': 40, 'freq': 1},
#  {'degree': 26, 'freq': 6},
#  {'degree': 114, 'freq': 1},
#  {'degree': 23, 'freq': 10},
#  {'degree': 8, 'freq': 178},
#  {'degree': 75, 'freq': 1},
#  {'degree': 58, 'freq': 1},
#  {'degree': 246, 'freq': 1},
#  {'degree': 30, 'freq': 3},
#  {'degree': 51, 'freq': 1},
#  {'degree': 19, 'freq': 15},
#  {'degree': 4, 'freq': 2414},
#  {'degree': 47, 'freq': 1},
#  {'degree': 15, 'freq': 28},
#  {'degree': 83, 'freq': 1},
#  {'degree': 100, 'freq': 1}]

# %%
for line in withOriginals:
    for i in range(line['freq']):
        oriExpanded.append(line['degree'])

# %%
for line in answers:
    for i in range(line['freq']):
        ansExpanded.append(line['weight'])

# %%
plt.boxplot([oriExpanded,ansExpanded])
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6243ae0640>,
#   <matplotlib.lines.Line2D at 0x7f6243ae09a0>,
#   <matplotlib.lines.Line2D at 0x7f6243aede20>,
#   <matplotlib.lines.Line2D at 0x7f6243af81c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6243ae0d00>,
#   <matplotlib.lines.Line2D at 0x7f6243aed0a0>,
#   <matplotlib.lines.Line2D at 0x7f6243af8520>,
#   <matplotlib.lines.Line2D at 0x7f6243af8880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6243ae02e0>,
#   <matplotlib.lines.Line2D at 0x7f6243aedac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6243aed400>,
#   <matplotlib.lines.Line2D at 0x7f6243af8be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6243aed760>,
#   <matplotlib.lines.Line2D at 0x7f6243af8f40>],
#  'means': []}
