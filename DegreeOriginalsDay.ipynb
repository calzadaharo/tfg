# %%
matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import json

# %%
with open('DegreeOriginalsDayDraw.json') as file:
    output=json.load(file)

# %%
output
# Out:
# {'views': [{'time': 19267200,
#    'originals': 23,
#    'answers': 6,
#    "don't-know": 0,
#    'relation': 0.2608695652173913,
#    'original-per-answer': 3.8333333333333335,
#    'percentage-originals': 79.3103448275862,
#    'percentage-answers': 20.689655172413794},
#   {'time': 19353600,
#    'originals': 20,
#    'answers': 1,
#    "don't-know": 0,
#    'relation': 0.05,
#    'original-per-answer': 20.0,
#    'percentage-originals': 95.23809523809523,
#    'percentage-answers': 4.761904761904762},
#   {'time': 19440000,
#    'originals': 10,
#    'answers': 2,
#    "don't-know": 0,
#    'relation': 0.2,
#    'original-per-answer': 5.0,
#    'percentage-originals': 83.33333333333334,
#    'percentage-answers': 16.666666666666664},
#   {'time': 19526400,
#    'originals': 8,
#    'answers': 4,
#    "don't-know": 0,
#    'relation': 0.5,
#    'original-per-answer': 2.0,
#    'percentage-originals': 66.66666666666666,
#    'percentage-answers': 33.33333333333333},
#   {'time': 19612800,
#    'originals': 18,
#    'answers': 13,
#    "don't-know": 0,
#    'relation': 0.7222222222222222,
#    'original-per-answer': 1.3846153846153846,
#    'percentage-originals': 58.06451612903226,
#    'percentage-answers': 41.935483870967744},
#   {'time': 19699200,
#    'originals': 120,
#    'answers': 26,
#    "don't-know": 0,
#    'relation': 0.21666666666666667,
#    'original-per-answer': 4.615384615384615,
#    'percentage-originals': 82.1917808219178,
#    'percentage-answers': 17.80821917808219},
#   {'time': 19785600,
#    'originals': 499,
#    'answers': 336,
#    "don't-know": 19,
#    'relation': 0.6733466933867736,
#    'original-per-answer': 1.4851190476190477,
#    'percentage-originals': 59.76047904191617,
#    'percentage-answers': 40.23952095808383},
#   {'time': 19872000,
#    'originals': 450,
#    'answers': 341,
#    "don't-know": 40,
#    'relation': 0.7577777777777778,
#    'original-per-answer': 1.3196480938416422,
#    'percentage-originals': 56.89001264222503,
#    'percentage-answers': 43.10998735777497},
#   {'time': 19958400,
#    'originals': 640,
#    'answers': 480,
#    "don't-know": 44,
#    'relation': 0.75,
#    'original-per-answer': 1.3333333333333333,
#    'percentage-originals': 57.14285714285714,
#    'percentage-answers': 42.857142857142854},
#   {'time': 20044800,
#    'originals': 703,
#    'answers': 481,
#    "don't-know": 9,
#    'relation': 0.6842105263157895,
#    'original-per-answer': 1.4615384615384615,
#    'percentage-originals': 59.375,
#    'percentage-answers': 40.625},
#   {'time': 20131200,
#    'originals': 1531,
#    'answers': 955,
#    "don't-know": 13,
#    'relation': 0.6237753102547354,
#    'original-per-answer': 1.6031413612565446,
#    'percentage-originals': 61.58487530168946,
#    'percentage-answers': 38.415124698310535},
#   {'time': 20217600,
#    'originals': 2052,
#    'answers': 1442,
#    "don't-know": 12,
#    'relation': 0.702729044834308,
#    'original-per-answer': 1.4230235783633842,
#    'percentage-originals': 58.72925014310246,
#    'percentage-answers': 41.27074985689754},
#   {'time': 20304000,
#    'originals': 1920,
#    'answers': 1689,
#    "don't-know": 16,
#    'relation': 0.8796875,
#    'original-per-answer': 1.1367673179396094,
#    'percentage-originals': 53.20033250207814,
#    'percentage-answers': 46.79966749792186},
#   {'time': 20390400,
#    'originals': 2948,
#    'answers': 2484,
#    "don't-know": 59,
#    'relation': 0.8426051560379919,
#    'original-per-answer': 1.1867954911433172,
#    'percentage-originals': 54.27098674521355,
#    'percentage-answers': 45.72901325478645},
#   {'time': 20476800,
#    'originals': 4383,
#    'answers': 3571,
#    "don't-know": 138,
#    'relation': 0.8147387634040612,
#    'original-per-answer': 1.227387286474377,
#    'percentage-originals': 55.10435001257229,
#    'percentage-answers': 44.89564998742771},
#   {'time': 20563200,
#    'originals': 4110,
#    'answers': 3301,
#    "don't-know": 250,
#    'relation': 0.8031630170316302,
#    'original-per-answer': 1.2450772493183884,
#    'percentage-originals': 55.45810282013224,
#    'percentage-answers': 44.54189717986776},
#   {'time': 20649600,
#    'originals': 4007,
#    'answers': 3386,
#    "don't-know": 252,
#    'relation': 0.8450212128774645,
#    'original-per-answer': 1.183402244536326,
#    'percentage-originals': 54.19991884214797,
#    'percentage-answers': 45.80008115785203},
#   {'time': 20736000,
#    'originals': 4866,
#    'answers': 3271,
#    "don't-know": 216,
#    'relation': 0.6722153719687628,
#    'original-per-answer': 1.4876184653011313,
#    'percentage-originals': 59.800909426078405,
#    'percentage-answers': 40.199090573921595},
#   {'time': 20822400,
#    'originals': 5229,
#    'answers': 3994,
#    "don't-know": 148,
#    'relation': 0.7638171734557276,
#    'original-per-answer': 1.3092138207310966,
#    'percentage-originals': 56.695218475550256,
#    'percentage-answers': 43.304781524449744},
#   {'time': 20908800,
#    'originals': 6282,
#    'answers': 3203,
#    "don't-know": 160,
#    'relation': 0.5098694683221904,
#    'original-per-answer': 1.961286294099282,
#    'percentage-originals': 66.23089088033738,
#    'percentage-answers': 33.76910911966263},
#   {'time': 20995200,
#    'originals': 5472,
#    'answers': 3839,
#    "don't-know": 225,
#    'relation': 0.7015716374269005,
#    'original-per-answer': 1.4253711904141704,
#    'percentage-originals': 58.76919772312319,
#    'percentage-answers': 41.23080227687681},
#   {'time': 21081600,
#    'originals': 6300,
#    'answers': 4224,
#    "don't-know": 142,
#    'relation': 0.6704761904761904,
#    'original-per-answer': 1.4914772727272727,
#    'percentage-originals': 59.863169897377425,
#    'percentage-answers': 40.136830102622575},
#   {'time': 21168000,
#    'originals': 6170,
#    'answers': 4321,
#    "don't-know": 162,
#    'relation': 0.70032414910859,
#    'original-per-answer': 1.42791020597084,
#    'percentage-originals': 58.81231531789153,
#    'percentage-answers': 41.18768468210847},
#   {'time': 21254400,
#    'originals': 6582,
#    'answers': 4310,
#    "don't-know": 164,
#    'relation': 0.6548161652993011,
#    'original-per-answer': 1.5271461716937356,
#    'percentage-originals': 60.429673154608885,
#    'percentage-answers': 39.570326845391115},
#   {'time': 21340800,
#    'originals': 6601,
#    'answers': 4468,
#    "don't-know": 189,
#    'relation': 0.6768671413422209,
#    'original-per-answer': 1.477394807520143,
#    'percentage-originals': 59.63501671334357,
#    'percentage-answers': 40.364983286656425},
#   {'time': 21427200,
#    'originals': 6487,
#    'answers': 3730,
#    "don't-know": 156,
#    'relation': 0.5749961461384308,
#    'original-per-answer': 1.7391420911528148,
#    'percentage-originals': 63.49221885093471,
#    'percentage-answers': 36.50778114906528},
#   {'time': 21513600,
#    'originals': 6204,
#    'answers': 3988,
#    "don't-know": 164,
#    'relation': 0.6428110896196002,
#    'original-per-answer': 1.5556670010030091,
#    'percentage-originals': 60.871271585557295,
#    'percentage-answers': 39.1287284144427},
#   {'time': 21600000,
#    'originals': 6438,
#    'answers': 3874,
#    "don't-know": 197,
#    'relation': 0.601739670705188,
#    'original-per-answer': 1.6618482188951986,
#    'percentage-originals': 62.43211792086889,
#    'percentage-answers': 37.56788207913111},
#   {'time': 21686400,
#    'originals': 5960,
#    'answers': 3748,
#    "don't-know": 219,
#    'relation': 0.6288590604026846,
#    'original-per-answer': 1.5901814300960513,
#    'percentage-originals': 61.39266584260403,
#    'percentage-answers': 38.60733415739596},
#   {'time': 21772800,
#    'originals': 5839,
#    'answers': 3820,
#    "don't-know": 224,
#    'relation': 0.6542216132899469,
#    'original-per-answer': 1.5285340314136127,
#    'percentage-originals': 60.451392483693965,
#    'percentage-answers': 39.548607516306035},
#   {'time': 21859200,
#    'originals': 6000,
#    'answers': 3924,
#    "don't-know": 260,
#    'relation': 0.654,
#    'original-per-answer': 1.529051987767584,
#    'percentage-originals': 60.45949214026602,
#    'percentage-answers': 39.54050785973398},
#   {'time': 21945600,
#    'originals': 5990,
#    'answers': 3270,
#    "don't-know": 192,
#    'relation': 0.5459098497495827,
#    'original-per-answer': 1.8318042813455657,
#    'percentage-originals': 64.68682505399568,
#    'percentage-answers': 35.313174946004324},
#   {'time': 22032000,
#    'originals': 7767,
#    'answers': 3872,
#    "don't-know": 189,
#    'relation': 0.49851937685077896,
#    'original-per-answer': 2.005940082644628,
#    'percentage-originals': 66.73253715954979,
#    'percentage-answers': 33.267462840450214},
#   {'time': 22118400,
#    'originals': 7574,
#    'answers': 4553,
#    "don't-know": 309,
#    'relation': 0.6011354634275152,
#    'original-per-answer': 1.6635185591917416,
#    'percentage-originals': 62.455677414034795,
#    'percentage-answers': 37.5443225859652},
#   {'time': 22204800,
#    'originals': 7223,
#    'answers': 4002,
#    "don't-know": 224,
#    'relation': 0.5540634085560017,
#    'original-per-answer': 1.804847576211894,
#    'percentage-originals': 64.34743875278397,
#    'percentage-answers': 35.652561247216035},
#   {'time': 22291200,
#    'originals': 6720,
#    'answers': 3841,
#    "don't-know": 215,
#    'relation': 0.571577380952381,
#    'original-per-answer': 1.7495443894819056,
#    'percentage-originals': 63.63033803617082,
#    'percentage-answers': 36.36966196382918},
#   {'time': 22377600,
#    'originals': 5849,
#    'answers': 3365,
#    "don't-know": 199,
#    'relation': 0.5753120191485724,
#    'original-per-answer': 1.7381872213967309,
#    'percentage-originals': 63.47948773605383,
#    'percentage-answers': 36.52051226394617},
#   {'time': 22464000,
#    'originals': 5775,
#    'answers': 3227,
#    "don't-know": 207,
#    'relation': 0.5587878787878788,
#    'original-per-answer': 1.789587852494577,
#    'percentage-originals': 64.1524105754277,
#    'percentage-answers': 35.84758942457232},
#   {'time': 22550400,
#    'originals': 4763,
#    'answers': 2783,
#    "don't-know": 200,
#    'relation': 0.5842956120092379,
#    'original-per-answer': 1.7114624505928855,
#    'percentage-originals': 63.11953352769679,
#    'percentage-answers': 36.88046647230321},
#   {'time': 22636800,
#    'originals': 5540,
#    'answers': 3423,
#    "don't-know": 343,
#    'relation': 0.617870036101083,
#    'original-per-answer': 1.6184633362547474,
#    'percentage-originals': 61.80966194354569,
#    'percentage-answers': 38.190338056454316},
#   {'time': 22723200,
#    'originals': 5991,
#    'answers': 3844,
#    "don't-know": 247,
#    'relation': 0.641629110332165,
#    'original-per-answer': 1.5585327783558791,
#    'percentage-originals': 60.9150991357397,
#    'percentage-answers': 39.0849008642603},
#   {'time': 22809600,
#    'originals': 5248,
#    'answers': 3482,
#    "don't-know": 207,
#    'relation': 0.6634908536585366,
#    'original-per-answer': 1.5071797817346353,
#    'percentage-originals': 60.11454753722795,
#    'percentage-answers': 39.88545246277205},
#   {'time': 22896000,
#    'originals': 6373,
#    'answers': 2878,
#    "don't-know": 178,
#    'relation': 0.45159265651969244,
#    'original-per-answer': 2.2143849895760948,
#    'percentage-originals': 68.88984974597341,
#    'percentage-answers': 31.110150254026593},
#   {'time': 22982400,
#    'originals': 7400,
#    'answers': 4898,
#    "don't-know": 251,
#    'relation': 0.6618918918918919,
#    'original-per-answer': 1.5108207431604737,
#    'percentage-originals': 60.1723857537811,
#    'percentage-answers': 39.82761424621889},
#   {'time': 23068800,
#    'originals': 7518,
#    'answers': 4540,
#    "don't-know": 251,
#    'relation': 0.6038840117052408,
#    'original-per-answer': 1.6559471365638767,
#    'percentage-originals': 62.3486482003649,
#    'percentage-answers': 37.651351799635094},
#   {'time': 23155200,
#    'originals': 6025,
#    'answers': 4145,
#    "don't-know": 229,
#    'relation': 0.6879668049792531,
#    'original-per-answer': 1.453558504221954,
#    'percentage-originals': 59.24287118977385,
#    'percentage-answers': 40.757128810226156},
#   {'time': 23241600,
#    'originals': 5161,
#    'answers': 3306,
#    "don't-know": 277,
#    'relation': 0.6405735322611897,
#    'original-per-answer': 1.5611010284331517,
#    'percentage-originals': 60.95429313806543,
#    'percentage-answers': 39.04570686193457},
#   {'time': 23328000,
#    'originals': 9194,
#    'answers': 3840,
#    "don't-know": 215,
#    'relation': 0.41766369371329126,
#    'original-per-answer': 2.3942708333333336,
#    'percentage-originals': 70.53859137640018,
#    'percentage-answers': 29.461408623599816},
#   {'time': 23414400,
#    'originals': 5403,
#    'answers': 3914,
#    "don't-know": 205,
#    'relation': 0.7244123635017583,
#    'original-per-answer': 1.3804292284108328,
#    'percentage-originals': 57.990769561017494,
#    'percentage-answers': 42.009230438982506},
#   {'time': 23500800,
#    'originals': 6088,
#    'answers': 4026,
#    "don't-know": 171,
#    'relation': 0.6613009198423128,
#    'original-per-answer': 1.5121708892200696,
#    'percentage-originals': 60.193790785050425,
#    'percentage-answers': 39.806209214949575},
#   {'time': 23587200,
#    'originals': 6257,
#    'answers': 3896,
#    "don't-know": 196,
#    'relation': 0.6226626178679878,
#    'original-per-answer': 1.6060061601642712,
#    'percentage-originals': 61.62710528907712,
#    'percentage-answers': 38.37289471092288},
#   {'time': 23673600,
#    'originals': 6111,
#    'answers': 3975,
#    "don't-know": 225,
#    'relation': 0.6504663721158567,
#    'original-per-answer': 1.5373584905660378,
#    'percentage-originals': 60.588935157644265,
#    'percentage-answers': 39.41106484235574},
#   {'time': 23760000,
#    'originals': 5100,
#    'answers': 3405,
#    "don't-know": 161,
#    'relation': 0.6676470588235294,
#    'original-per-answer': 1.497797356828194,
#    'percentage-originals': 59.9647266313933,
#    'percentage-answers': 40.0352733686067},
#   {'time': 23846400,
#    'originals': 4810,
#    'answers': 3275,
#    "don't-know": 167,
#    'relation': 0.6808731808731808,
#    'original-per-answer': 1.468702290076336,
#    'percentage-originals': 59.49288806431664,
#    'percentage-answers': 40.50711193568336},
#   {'time': 23932800,
#    'originals': 5731,
#    'answers': 3790,
#    "don't-know": 223,
#    'relation': 0.6613156517187228,
#    'original-per-answer': 1.5121372031662268,
#    'percentage-originals': 60.19325701081819,
#    'percentage-answers': 39.80674298918181},
#   {'time': 24019200,
#    'originals': 8182,
#    'answers': 4523,
#    "don't-know": 257,
#    'relation': 0.5527988266927402,
#    'original-per-answer': 1.8089763431350874,
#    'percentage-originals': 64.39984258166076,
#    'percentage-answers': 35.600157418339236},
#   {'time': 24105600,
#    'originals': 6672,
#    'answers': 4111,
#    "don't-know": 210,
#    'relation': 0.6161570743405276,
#    'original-per-answer': 1.622962782777913,
#    'percentage-originals': 61.8751738848187,
#    'percentage-answers': 38.12482611518131},
#   {'time': 24192000,
#    'originals': 7542,
#    'answers': 5297,
#    "don't-know": 235,
#    'relation': 0.7023335985149828,
#    'original-per-answer': 1.423824806494242,
#    'percentage-originals': 58.74289274865644,
#    'percentage-answers': 41.25710725134356},
#   {'time': 24278400,
#    'originals': 7633,
#    'answers': 5380,
#    "don't-know": 266,
#    'relation': 0.7048342722389624,
#    'original-per-answer': 1.4187732342007433,
#    'percentage-originals': 58.65672788749712,
#    'percentage-answers': 41.34327211250288},
#   {'time': 24364800,
#    'originals': 7977,
#    'answers': 5157,
#    "don't-know": 114,
#    'relation': 0.6464836404663408,
#    'original-per-answer': 1.546829552065154,
#    'percentage-originals': 60.73549566011878,
#    'percentage-answers': 39.26450433988122},
#   {'time': 24451200,
#    'originals': 12635,
#    'answers': 5895,
#    "don't-know": 240,
#    'relation': 0.4665611396913336,
#    'original-per-answer': 2.14334181509754,
#    'percentage-originals': 68.1867242309768,
#    'percentage-answers': 31.813275769023207},
#   {'time': 24511068,
#    'originals': 13341,
#    'answers': 5487,
#    "don't-know": 223,
#    'relation': 0.41128850910726333,
#    'original-per-answer': 2.4313832695462,
#    'percentage-originals': 70.8572339069471,
#    'percentage-answers': 29.142766093052902}]}

# %%
originals=[]; answers=[]; times=[]; degrees=[];data=[]

# %%
for result in output['views']:
    line=[]
    line.append(result['originals'])
    line.append(result['answers'])
    times.append(result['time']/60/60/24)
    line.append(result['original-per-answer'])
    data.append(line)

# %%
df = pd.DataFrame(data,columns=['Originales','Respuestas','Relación'],index=times)

# %%
df.plot(color=['darkblue','darkorange','green'])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
plt.yscale('log')

# %%
plt.title('Relación entre mensajes originales y respuestas cada día')
# Out:
# Text(0.5, 1.0, 'Relación entre mensajes originales y respuestas cada día')
